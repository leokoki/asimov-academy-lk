# %%
import requests
from bs4 import BeautifulSoup

# %%
globo_url = 'https://www.globo.com/'
page = requests.get(globo_url)

# %%
page
# Out:
# <Response [200]>

# %%
resposta = page.text

# %%
soup = BeautifulSoup(resposta, 'html.parser')

# %%
noticias = soup.find_all('h2',{'class':'post__title'})

# %%
noticias
# Out:
# [<h2 class="post__title">Real x Barça tem 3 gols em menos de 5 min na final da Supercopa; SIGA</h2>,
#  <h2 class="post__title">Corinthians estreia contra a Ponte Preta; siga os lances</h2>,
#  <h2 class="post__title">Data e horário: Fla x Timão pela Supercopa Rei</h2>,
#  <h2 class="post__title">Atriz Titina Medeiros morre aos 48 com câncer de pâncreas</h2>,
#  <h2 class="post__title">Marido também atuou em 'Cheias de charme'</h2>,
#  <h2 class="post__title">PM morto em SP foi 'julgado' por tráfico: 'Lugar errado'</h2>,
#  <h2 class="post__title">Marido foge após arrastar mulher pelos cabelos</h2>,
#  <h2 class="post__title">Amigos e familiares vão ao velório de Manoel Carlos no Rio</h2>,
#  <h2 class="post__title">Christiane Torloni presta homenagem</h2>,
#  <h2 class="post__title">Serra das Araras fechará hoje à noite no sentido SP</h2>,
#  <h2 class="post__title">O alerta pra riscos do turismo predatório</h2>,
#  <h2 class="post__title">Trump refaz ameaça a Cuba: 'Faça acordo antes que seja tarde'</h2>,
#  <h2 class="post__title">Presidente de Cuba: ilha 'pronta para se defender'</h2>,
#  <h2 class="post__title">Copinha conhece os 32 duelos da 2ª fase; veja</h2>,
#  <h2 class="post__title">United perde para o Brighton e está fora da Copa da Inglaterra</h2>,
#  <h2 class="post__title">Algoz do Cruzeiro, meia estava banido e jogou Kings League </h2>,
#  <h2 class="post__title">Torino aumenta a proposta e insiste por Arthur Cabral, do Bota</h2>,
#  <h2 class="post__title">Fla pega a Portuguesa; onde ver</h2>,
#  <h2 class="post__title">Após fazer malas, Marcel diz ao vivo que não sairá da Casa de Vidro Sudeste</h2>,
#  <h2 class="post__title">Quem deve ficar? VOTE</h2>,
#  <h2 class="post__title">Ex-BBBs Gustavo e Laís visitam a Casa de Vidro Sul: 'Não façam casal'</h2>,
#  <h2 class="post__title">É hoje! Sabe tudo sobre o Globo de Ouro? Faça teste</h2>,
#  <h2 class="post__title">Manoel Carlos mudou final de personagem após Dieckmmann perder bebê</h2>,
#  <h2 class="post__title">Grêmio anuncia a contratação de atacante que estava no Junior Barranquilla; conheça</h2>,
#  <h2 class="post__title">Confira oito dicas importantes do que não fazer com seu ventilador</h2>,
#  <h2 class="post__title">Veja 4 carros usados com preço até R$ 25 mil para comprar</h2>,
#  <h2 class="post__title">Reação a tattoo faz homem perder fios, parar de suar e desenvolver vitiligo</h2>,
#  <h2 class="post__title">Melatonina vive boom de buscas no Brasil; veja as principais dúvidas</h2>,
#  <h2 class="post__title">Meta de ano novo: o caminho de quem quer emagrecer sem 'caneta' em 2026</h2>,
#  <h2 class="post__title">Verão escaldante: um guia para manter a pele nutrida, hidratada e segura</h2>,
#  <h2 class="post__title">Viviane Araujo entra na trama para impedir tragédia </h2>,
#  <h2 class="post__title">Estela fica desesperada com a morte de Miriam; resumo</h2>,
#  <h2 class="post__title">Perdeu o último capítulo? Veja todos os desfechos</h2>,
#  <h2 class="post__title">Amor entre primos, última Helena e Marquezine: relembre 'Em Família'</h2>,
#  <h2 class="post__title">O que é e como evitar o cloaking, comportamento pior que o ghosting</h2>,
#  <h2 class="post__title">Idosa viraliza em show de pagode: 'Ninguém se mete na minha vida'</h2>,
#  <h2 class="post__title">Pai deixa filha sozinha por um segundo e se choca com 'fuga'; vídeo</h2>,
#  <h2 class="post__title">Tutora lamenta morte de cão picado por coral: 'Ele se foi nos protegendo'</h2>,
#  <h2 class="post__title">Apresentadora retorna ao Globo de Ouro após piadas sobre Brady e Gisele</h2>,
#  <h2 class="post__title">Por dentro de 'Frankenstein': os cenários reais que deram vida ao filme</h2>,
#  <h2 class="post__title">Cafés especiais impulsionam cultura e estilo de vida no consumo da bebida</h2>,
#  <h2 class="post__title">NYT elege as 10 canções fundamentais de Bob Weir, do Grateful Dad</h2>]

# %%
for i in range(len(noticias)):
    print(noticias[i].text)
# Out:
# Real x Barça tem 3 gols em menos de 5 min na final da Supercopa; SIGA
# Corinthians estreia contra a Ponte Preta; siga os lances
# Data e horário: Fla x Timão pela Supercopa Rei
# Atriz Titina Medeiros morre aos 48 com câncer de pâncreas
# Marido também atuou em 'Cheias de charme'
# PM morto em SP foi 'julgado' por tráfico: 'Lugar errado'
# Marido foge após arrastar mulher pelos cabelos
# Amigos e familiares vão ao velório de Manoel Carlos no Rio
# Christiane Torloni presta homenagem
# Serra das Araras fechará hoje à noite no sentido SP
# O alerta pra riscos do turismo predatório
# Trump refaz ameaça a Cuba: 'Faça acordo antes que seja tarde'
# Presidente de Cuba: ilha 'pronta para se defender'
# Copinha conhece os 32 duelos da 2ª fase; veja
# United perde para o Brighton e está fora da Copa da Inglaterra
# Algoz do Cruzeiro, meia estava banido e jogou Kings League
# Torino aumenta a proposta e insiste por Arthur Cabral, do Bota
# Fla pega a Portuguesa; onde ver
# Após fazer malas, Marcel diz ao vivo que não sairá da Casa de Vidro Sudeste
# Quem deve ficar? VOTE
# Ex-BBBs Gustavo e Laís visitam a Casa de Vidro Sul: 'Não façam casal'
# É hoje! Sabe tudo sobre o Globo de Ouro? Faça teste
# Manoel Carlos mudou final de personagem após Dieckmmann perder bebê
# Grêmio anuncia a contratação de atacante que estava no Junior Barranquilla; conheça
# Confira oito dicas importantes do que não fazer com seu ventilador
# Veja 4 carros usados com preço até R$ 25 mil para comprar
# Reação a tattoo faz homem perder fios, parar de suar e desenvolver vitiligo
# Melatonina vive boom de buscas no Brasil; veja as principais dúvidas
# Meta de ano novo: o caminho de quem quer emagrecer sem 'caneta' em 2026
# Verão escaldante: um guia para manter a pele nutrida, hidratada e segura
# Viviane Araujo entra na trama para impedir tragédia
# Estela fica desesperada com a morte de Miriam; resumo
# Perdeu o último capítulo? Veja todos os desfechos
# Amor entre primos, última Helena e Marquezine: relembre 'Em Família'
# O que é e como evitar o cloaking, comportamento pior que o ghosting
# Idosa viraliza em show de pagode: 'Ninguém se mete na minha vida'
# Pai deixa filha sozinha por um segundo e se choca com 'fuga'; vídeo
# Tutora lamenta morte de cão picado por coral: 'Ele se foi nos protegendo'
# Apresentadora retorna ao Globo de Ouro após piadas sobre Brady e Gisele
# Por dentro de 'Frankenstein': os cenários reais que deram vida ao filme
# Cafés especiais impulsionam cultura e estilo de vida no consumo da bebida
# NYT elege as 10 canções fundamentais de Bob Weir, do Grateful Dad
